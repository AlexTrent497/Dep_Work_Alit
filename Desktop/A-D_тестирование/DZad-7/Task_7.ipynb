# %% [markdown]
# Урок 7. Нестандартные ситуации
# На основе выбранных продуктов из первого вебинара, выберите 2 A/B-теста и составьте план эксперимента, чтобы избежать Peeking Problem
#
# Распишите, какие метрики и как вы будете анализировать

# %% [markdown]
# 2. Если добавить в приложение план-схемы велосипедных дорожек
# (если они присутствуют в населённом пункте) то это дополнительно привлечёт любителей активного отдыха и может увеличить время пользования приложением и число посещений.

# %% [markdown]
# Гипотеза 2:
#
# Impact - 9
#
# Confidence - 8
#
# Ease - 7
#
# 504

# %% [markdown]
# 1. Из всех активных  и новых пользователей выбираем любителей активного отдыха и предпочитающих передвигаться на велосипедах.
# 2. Делим на 2 тестовые группы.
# 3. 1-й группе даём обычную версию сайти 2-й даём изменённую версию
# 4. Праверяем время пользования сайтом и сравнив зто время у каждой из групп.

# %% [markdown]
# Пользователи: Все выбранные
#
# 1-я группа; с обычной версией
#
# 2-я группа; с изменённой версией
#
# Показатель; время нахождения на сайте и число посещений

# %% [markdown]
# Может подайти Яндех метрика и X квадрат

# %% [markdown]
# 4. Если добавить на план-схему расположение АЗС и наличия на них горючего
# определённой марки (лучше в реальном времени ) то с очень большой вероятностью это может привлечь огромное количество владельцев авто и другого транспорта

# %% [markdown]
# 1. Все активные и новые пользователи
# 2. Делятся на 2-е тестовае группы
# 3. 1-й обычную 2-й изменённую версию сайта
# 4. Проверяем увеличения числа пользователей

# %% [markdown]
# Пользователи: Все активные и новые пользователи
#
# 1-я Группа; с обычной версией
#
# 2=я Группа; с изменённой версией сайта
#
# Показатель; Процент увеличения активных пользователей.

# %% [markdown]
# Здесь можно использовать Яндекс метрику и Тест Пуассона
